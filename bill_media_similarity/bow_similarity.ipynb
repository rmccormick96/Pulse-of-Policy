# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
torch.manual_seed(1)

# %%
import pandas as pd 

bill_df = pd.read_csv("115th_clean.csv")

# %%
bill_df.columns
# Out:
# Index(['bill_id', 'bill_slug', 'bill_type', 'number', 'bill_uri', 'title',
#        'short_title', 'sponsor_title', 'sponsor_id', 'sponsor_name',
#        'sponsor_state', 'sponsor_party', 'sponsor_uri', 'gpo_pdf_uri',
#        'congressdotgov_url', 'govtrack_url', 'introduced_date', 'active',
#        'last_vote', 'house_passage', 'senate_passage', 'enacted', 'vetoed',
#        'cosponsors', 'cosponsors_by_party', 'committees', 'committee_codes',
#        'subcommittee_codes', 'primary_subject', 'summary', 'summary_short',
#        'latest_major_action_date', 'latest_major_action', 'raw_text',
#        'new_index', 'cleaned_text', 'date'],
#       dtype='object')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
import numpy as np
from torchtext.vocab import GloVe
glove = GloVe(name='6B')

# %%
def get_top_words_bills(bill):
    
    custom_stop_words = list(ENGLISH_STOP_WORDS.union({'additional', 'stopwords'}))
    vectorizer = TfidfVectorizer(stop_words=custom_stop_words)
    
    
    tfidf_matrix = vectorizer.fit_transform([bill])

    feature_array = vectorizer.get_feature_names_out()
    tfidf_sorting = np.argsort(tfidf_matrix.toarray().flatten())[::-1]

    n = 10

    top_n = feature_array[tfidf_sorting][:n].tolist()
    return top_n

# %%
get_top_words_bills(bill_df.loc[0]['cleaned_text'])
# Out:
# ['section',
#  'refugee',
#  'act',
#  'shall',
#  'alien',
#  'states',
#  'resettlement',
#  'united',
#  'granted',
#  'status']

# %%
bill_df['keywords'] = bill_df['cleaned_text'].apply(get_top_words_bills)

# %%
bill_df['introduced_date'] = pd.to_datetime(bill_df['introduced_date'])

# %%
start_date = '2017-01-01'
end_date = '2017-10-31'
bill_df = bill_df.loc[(bill_df['introduced_date'] >= start_date) & (bill_df['introduced_date'] <= end_date), :]

# %%
print(bill_df['keywords'])
# Out:
# 3884    [violence, domestic, sexual, assault, stalking...
# 3885    [columbia, district, national, guard, assistan...
# 3886    [president, law, mr, states, spouse, constitut...
# 3887    [institution, funds, section, subsection, educ...
# 3888    [inserting, order, united, title, partner, sta...
#                               ...
# 8871    [security, transportation, systems, transit, n...
# 8872    [isil, resolution, states, 2014, congress, uni...
# 8873    [johnson, judge, decision, alabama, montgomery...
# 8874    [house, senate, leader, representatives, congr...
# 8875    [representatives, house, clerk, elected, state...
# Name: keywords, Length: 4992, dtype: object

# %%
topic_df = pd.read_json("final_topics_dict.json")

# %%
print(topic_df.head())
# Out:
#                                               201701  \
# 0  [obamacare, health, insurance, care, repeal, m...
# 1  [0.008568612132015001, 0.008531346294839, 0.00...
# 2                                           0.363346
#
#                                               201702  \
# 0  [obamacare, health, insurance, care, repeal, b...
# 1  [0.008737137061722001, 0.008435196697133001, 0...
# 2                                           0.363346
#
#                                               201703  \
# 0  [obamacare, health, insurance, care, bill, rep...
# 1  [0.008436168128663001, 0.008163779397270001, 0...
# 2                                           0.363346
#
#                                               201704  \
# 0  [de, que, la, en, el, una, los, un, las, del, ...
# 1  [0.08658085063946801, 0.063443773607105, 0.060...
# 2                                           0.363346
#
#                                               201705  \
# 0  [de, la, que, en, el, los, una, un, del, se, r...
# 1  [0.08306230026877501, 0.061556571959935004, 0....
# 2                                           0.363346
#
#                                               201706  \
# 0  [de, que, la, en, el, los, una, un, del, se, n...
# 1  [0.08416654088198, 0.06312325304013701, 0.0617...
# 2                                           0.363346
#
#                                               201707  \
# 0  [de, que, la, en, el, una, los, un, se, del, a...
# 1  [0.081934148092971, 0.06061393023604401, 0.060...
# 2                                           0.363346
#
#                                               201708  \
# 0  [de, que, la, en, el, una, los, un, se, del, k...
# 1  [0.08297005410937601, 0.061633858544775, 0.060...
# 2                                           0.363346
#
#                                               201709  \
# 0  [nationals, baseball, game, innings, yankees, ...
# 1  [0.013784365651942002, 0.0062622362426320004, ...
# 2                                           0.363346
#
#                                               201710
# 0  [tax, bill, taxes, cuts, republicans, plan, in...
# 1  [0.018572639121045002, 0.007938152378464, 0.00...
# 2                                           0.363346

# %%
dates = []
topics_list = []
weights_list = []
summed_values = []

for date, data in topic_df.items():

    formatted_date = f"{str(date)[:4]}-{str(date)[4:]}"
    
    dates.append(formatted_date)

    topics_list.append(data[0])
    weights_list.append(data[1])

topic_df = pd.DataFrame({
    "date": dates,
    "topics": topics_list,
    "weights": weights_list,
})

print(topic_df)
# Out:
#       date                                             topics  \
# 0  2017-01  [obamacare, health, insurance, care, repeal, m...
# 1  2017-02  [obamacare, health, insurance, care, repeal, b...
# 2  2017-03  [obamacare, health, insurance, care, bill, rep...
# 3  2017-04  [de, que, la, en, el, una, los, un, las, del, ...
# 4  2017-05  [de, la, que, en, el, los, una, un, del, se, r...
# 5  2017-06  [de, que, la, en, el, los, una, un, del, se, n...
# 6  2017-07  [de, que, la, en, el, una, los, un, se, del, a...
# 7  2017-08  [de, que, la, en, el, una, los, un, se, del, k...
# 8  2017-09  [nationals, baseball, game, innings, yankees, ...
# 9  2017-10  [tax, bill, taxes, cuts, republicans, plan, in...
#
#                                              weights
# 0  [0.008568612132015001, 0.008531346294839, 0.00...
# 1  [0.008737137061722001, 0.008435196697133001, 0...
# 2  [0.008436168128663001, 0.008163779397270001, 0...
# 3  [0.08658085063946801, 0.063443773607105, 0.060...
# 4  [0.08306230026877501, 0.061556571959935004, 0....
# 5  [0.08416654088198, 0.06312325304013701, 0.0617...
# 6  [0.081934148092971, 0.06061393023604401, 0.060...
# 7  [0.08297005410937601, 0.061633858544775, 0.060...
# 8  [0.013784365651942002, 0.0062622362426320004, ...
# 9  [0.018572639121045002, 0.007938152378464, 0.00...

# %%
inspection_df = pd.read_excel('inspection.xlsx')
print(inspection_df.columns)

average_sentiments = []

for i in range(0, len(inspection_df), 50):
    subset = inspection_df.loc[i:i+49]
    average_sentiment = subset['mean_positive'].mean()
    average_sentiments.append(average_sentiment)

topic_df['average_sentiment'] = average_sentiments
# Out:
# Index(['Unnamed: 0', 'topics', 'topic_words', 'mean_positive', 'count',
#        'words', 'weights', 'Window'],
#       dtype='object')

# %%
def calculate_score(bill_keywords, topics_for_date, weights_for_date):

    matching_keywords = [keyword for keyword in bill_keywords if keyword in topics_for_date]
    score = sum(weights_for_date[topics_for_date.index(keyword)] for keyword in matching_keywords) / sum(weights_for_date) if sum(weights_for_date) > 0 else 0
    return score

# %%
def map_keywords_to_topics(bill_df, topics_df):
    
    bill_df['year_month'] = bill_df['introduced_date'].dt.to_period('M')
    
    mapped_scores = {}

    for _, row in bill_df.iterrows():
        year_month = str(row['year_month'])
        bill_keywords = row['keywords']
        
        if year_month in topics_df['date'].values:

            if year_month not in mapped_scores:
                mapped_scores[year_month] = []

            topics_row = topics_df[topics_df['date'] == year_month]
            topics_for_date = topics_row['topics'].iloc[0]
            weights_for_date = topics_row['weights'].iloc[0]
            sentiment_for_date = topics_row['average_sentiment'].iloc[0]

            score = calculate_score(bill_keywords, topics_for_date, weights_for_date)
            bill_df.loc[bill_df['date'] == row['date'], 'bow_similarity'] = score
            bill_df.loc[bill_df['date'] == row['date'], 'avg_media_sentiment'] = sentiment_for_date

            mapped_scores[year_month].append(score)

    return bill_df

# %%
map_keywords_to_topics(bill_df, topic_df)
# Out:
#            bill_id bill_slug bill_type       number  \
# 3884    hr4198-115    hr4198        hr     H.R.4198
# 3885    hr4194-115    hr4194        hr     H.R.4194
# 3886  hjres120-115  hjres120     hjres  H.J.RES.120
# 3887    hr4181-115    hr4181        hr     H.R.4181
# 3888    hr4186-115    hr4186        hr     H.R.4186
# ...            ...       ...       ...          ...
# 8871    hres13-115    hres13      hres     H.RES.13
# 8872  hconres2-115  hconres2   hconres  H.CON.RES.2
# 8873  hconres3-115  hconres3   hconres  H.CON.RES.3
# 8874  hconres1-115  hconres1   hconres  H.CON.RES.1
# 8875     hres2-115     hres2      hres      H.RES.2
#
#                                                bill_uri  \
# 3884  https://api.propublica.org/congress/v1/115/bil...
# 3885  https://api.propublica.org/congress/v1/115/bil...
# 3886  https://api.propublica.org/congress/v1/115/bil...
# 3887  https://api.propublica.org/congress/v1/115/bil...
# 3888  https://api.propublica.org/congress/v1/115/bil...
# ...                                                 ...
# 8871  https://api.propublica.org/congress/v1/115/bil...
# 8872  https://api.propublica.org/congress/v1/115/bil...
# 8873  https://api.propublica.org/congress/v1/115/bil...
# 8874  https://api.propublica.org/congress/v1/115/bil...
# 8875  https://api.propublica.org/congress/v1/115/bil...
#
#                                                   title  \
# 3884  To promote the economic security and safety of...
# 3885  To direct the Mayor of the District of Columbi...
# 3886  Proposing an amendment to the Constitution of ...
# 3887  To amend the Higher Education Act of 1965 rega...
# 3888  To amend title 18, United States Code, to prot...
# ...                                                 ...
# 8871  Expressing the sense of the House of Represent...
# 8872  To authorize the use of United States Armed Fo...
# 8873  Recognizing former United States Federal Judge...
# 8874  Regarding consent to assemble outside the seat...
# 8875  To inform the Senate that a quorum of the Hous...
#
#                                             short_title sponsor_title  \
# 3884     Security and Financial Empowerment Act of 2017          Rep.
# 3885  To direct the Mayor of the District of Columbi...          Del.
# 3886  Proposing an amendment to the Constitution of ...          Rep.
# 3887                                   POST Act of 2017          Rep.
# 3888  Lori Jackson Domestic Violence Survivor Protec...          Rep.
# ...                                                 ...           ...
# 8871  Expressing the sense of the House of Represent...          Rep.
# 8872  Authorization for Use of Military Force Agains...          Rep.
# 8873  Recognizing former United States Federal Judge...          Rep.
# 8874  Regarding consent to assemble outside the seat...          Rep.
# 8875  To inform the Senate that a quorum of the Hous...          Rep.
#
#      sponsor_id           sponsor_name  ... latest_major_action_date  \
# 3884    R000486  Lucille Roybal-Allard  ...               2017-10-31
# 3885    N000147  Eleanor Holmes Norton  ...               2017-10-31
# 3886    C001068            Steve Cohen  ...               2017-11-02
# 3887    C001068            Steve Cohen  ...               2017-10-31
# 3888    H001047              Jim Himes  ...               2017-11-17
# ...         ...                    ...  ...                      ...
# 8871    J000032     Sheila Jackson Lee  ...               2017-01-03
# 8872    C001053               Tom Cole  ...               2017-01-03
# 8873    G000553               Al Green  ...               2017-01-11
# 8874    S000250          Pete Sessions  ...               2017-01-04
# 8875    M001165         Kevin McCarthy  ...               2017-01-03
#
#                                     latest_major_action  \
# 3884  Referred to the Committee on Education and the...
# 3885  Referred to the House Committee on Oversight a...
# 3886  Sponsor introductory remarks on measure. (CR H...
# 3887  Referred to the House Committee on Education a...
# 3888  Referred to the Subcommittee on Crime, Terrori...
# ...                                                 ...
# 8871  Referred to the House Committee on Homeland Se...
# 8872  Referred to the House Committee on Foreign Aff...
# 8873  Referred to the Subcommittee on the Constituti...
# 8874                            Received in the Senate.
# 8875  Motion to reconsider laid on the table Agreed ...
#
#                                                raw_text  new_index  \
# 3884  [Congressional Bills 115th Congress]\n[From th...       3884
# 3885  [Congressional Bills 115th Congress]\n[From th...       3885
# 3886  [Congressional Bills 115th Congress]\n[From th...       3886
# 3887  [Congressional Bills 115th Congress]\n[From th...       3887
# 3888  [Congressional Bills 115th Congress]\n[From th...       3888
# ...                                                 ...        ...
# 8871  [Congressional Bills 115th Congress]\n[From th...       8871
# 8872  [Congressional Bills 115th Congress]\n[From th...       8872
# 8873  [Congressional Bills 115th Congress]\n[From th...       8873
# 8874  [Congressional Bills 115th Congress]\n[From th...       8874
# 8875  [Congressional Bills 115th Congress]\n[From th...       8875
#
#                                            cleaned_text        date  \
# 3884  115th congress 1st session h. r. 4198 to promo...  2017-10-31
# 3885  115th congress 1st session h. r. 4194 to direc...  2017-10-31
# 3886  115th congress 1st session h. j. res. 120 prop...  2017-10-31
# 3887  115th congress 1st session h. r. 4181 to amend...  2017-10-31
# 3888  115th congress 1st session h. r. 4186 to amend...  2017-10-31
# ...                                                 ...         ...
# 8871  115th congress 1st session h. res. 13 expressi...  2017-01-03
# 8872  115th congress 1st session h. con. res. 2 to a...  2017-01-03
# 8873  115th congress 1st session h. con. res. 3 reco...  2017-01-03
# 8874  115th congress 1st session h. con. res. 1 in t...  2017-01-03
# 8875  h. res. 2 in the house of representatives, u. ...  2017-01-03
#
#                                                keywords  year_month  \
# 3884  [violence, domestic, sexual, assault, stalking...     2017-10
# 3885  [columbia, district, national, guard, assistan...     2017-10
# 3886  [president, law, mr, states, spouse, constitut...     2017-10
# 3887  [institution, funds, section, subsection, educ...     2017-10
# 3888  [inserting, order, united, title, partner, sta...     2017-10
# ...                                                 ...         ...
# 8871  [security, transportation, systems, transit, n...     2017-01
# 8872  [isil, resolution, states, 2014, congress, uni...     2017-01
# 8873  [johnson, judge, decision, alabama, montgomery...     2017-01
# 8874  [house, senate, leader, representatives, congr...     2017-01
# 8875  [representatives, house, clerk, elected, state...     2017-01
#
#      bow_similarity avg_media_sentiment
# 3884       0.002746            0.338246
# 3885       0.002746            0.338246
# 3886       0.002746            0.338246
# 3887       0.002746            0.338246
# 3888       0.002746            0.338246
# ...             ...                 ...
# 8871       0.000865            0.376167
# 8872       0.000865            0.376167
# 8873       0.000865            0.376167
# 8874       0.000865            0.376167
# 8875       0.000865            0.376167
#
# [4992 rows x 41 columns]

# %%
unique_similarities = set()

for similarity in bill_df["bow_similarity"]:
    if similarity > 0:
        unique_similarities.add(similarity)

print("Unique Similarities")
for unique_similarity in unique_similarities:
    print(unique_similarity)
# Out:
# Unique Similarities
# 0.005470064958203791
# 0.001557443365920231
# 0.003454156055004321
# 0.002955230222877248
# 0.001443802693447573
# 0.0025918117813801297
# 0.0014466578787375496
# 0.005950485553869017
# 0.0015356569417557362
# 0.0019155981000607111
# 0.0027044251411541096
# 0.0023762756152545654
# 0.00287391667307137
# 0.003313266662626786
# 0.002121402222404552
# 0.0039096232830005025
# 0.00498979133394564
# 0.0011555489158008659
# 0.002288083845512859
# 0.0036076837954892985
# 0.0017926757241706788
# 0.002948974905081326
# 0.006210950295886527
# 0.0033447359534324846
# 0.003165257308103184
# 0.0023325697143073403
# 0.002876725015122315
# 0.0014689800937406924
# 0.007599620685887322
# 0.0020349672532272226
# 0.002329539254954336
# 0.009080886244284003
# 0.0017146119759564146
# 0.002488486664207048
# 0.002400620910398682
# 0.0005059369524212546
# 0.00278621184349189
# 0.001647059758141354
# 0.0014441125621101542
# 0.0038858437085243724
# 0.003004564018227542
# 0.0008647175449415223
# 0.0023707857502231755
# 0.001025635602304929
# 0.005814922992645278
# 0.0011584411192783017
# 0.0013656240808100734
# 0.007991779083924882
# 0.004520345845054103
# 0.000727248127080014
# 0.0020774919405083126
# 0.003199749945623654
# 0.0031124879398142166
# 0.0009842298251340133
# 0.007413428126294412
# 0.0054011417146436706
# 0.0081171202339777
# 0.0014558561941765383
# 0.0032963824987807234
# 0.0028532879176140767
# 0.004085821273421718
# 0.001476574471821369
# 0.0006284893355831281
# 0.005681021284259631
# 0.0006812208170151685
# 0.0007464355583909432
# 0.003544851417760632
# 0.004724451989327597
# 0.0031794481422299384
# 0.005954686701281313
# 0.0027458492049729105
# 0.0020424402807782847
# 0.004855722198879104
# 0.0031154346691017096
# 0.0027280032736666463
# 0.0033711787061105006
# 0.0013494363851641858
# 0.0028578669459275174
# 0.004138802007645743
# 0.0011517476735293573
# 0.0011204734703233253
# 0.0022280852214312894
# 0.000960437425343502
# 0.0020049010655502227
# 0.0027459681165970407
# 0.005143274648724485
# 0.00039618390814160465
# 0.0011324499330329018
# 0.0013017381014352434
# 0.0026888442083951563
# 0.00486005519935667
# 0.00245480058574227
# 0.008751132041775193
# 0.0013028113275956386
# 0.0022678067367180696
# 0.007644253208718155
# 0.013790687912233549
# 0.0011675741021392606
# 0.002322362645638977
# 0.00388105755849685
# 0.005766380309273314
# 0.0023788651956348746
# 0.002527032244836495
# 0.002017393970389106
# 0.0023296436106860817
# 0.0023002338984638767
# 0.004290527194648264
# 0.003152037398661971
# 0.0023125344280612134
# 0.005662679475282084
# 0.0019048766776692452
# 0.00142527930889779
# 0.0005432776111773346
# 0.0026105549336437003
# 0.0037598398818616792
# 0.0011219461971956315
# 0.003274475352122773

# %%
print("Number of Bills with some Similarity:", len(bill_df["bow_similarity"] > 0))
# Out:
# Number of Bills with some Similarity: 4992

# %%
print("Minimum Similarity:", min(bill_df['bow_similarity']))
print("Maximum Similarity:", max(bill_df['bow_similarity']))
# Out:
# Minimum Similarity: 0.0
# Maximum Similarity: 0.013790687912233549

# %%
bill_df.to_csv('bills_with_bow_similarity.csv', index=False)
